# %%
# %matplotlib inline
# %run hw3.py
# Out:
# Fitting 3 folds for each of 14 candidates, totalling 42 fits
# [CV] penalty=l1, C=1e-05 .............................................
# [CV] .................... penalty=l1, C=1e-05, score=0.703025 -   0.1s
# [CV] penalty=l1, C=1e-05 .............................................
# [CV] .................... penalty=l1, C=1e-05, score=0.703025 -   0.1s
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   2 jobs       | elapsed:    0.2s
# [CV] penalty=l1, C=1e-05 .............................................
# [CV] .................... penalty=l1, C=1e-05, score=0.703018 -   0.1s
# [CV] penalty=l2, C=1e-05 .............................................
# [CV] .................... penalty=l2, C=1e-05, score=0.947775 -   0.1s
# [CV] penalty=l2, C=1e-05 .............................................
# [CV] .................... penalty=l2, C=1e-05, score=0.946525 -   0.1s
# [CV] penalty=l2, C=1e-05 .............................................
# ...
