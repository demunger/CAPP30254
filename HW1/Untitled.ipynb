# %%
# %load hw1.py
import numpy as np
import pandas as p
import matplotlib as plt


filename = "mock_student_data.csv"
read_data(filename)

def read_data(filename):
	array = p.read_csv(filename, usecols = range(1, 9))

	mean = array.mean()
	median = array.median()
	mode = array.mode()
	standard_deviation = array.std()

	array.hist()

# %%
# %run hw1.py

# %%
# %load hw1.py
import numpy as np
import pandas as p
import matplotlib as plt


def read_data(filename):
	array = p.read_csv(filename, usecols = range(1, 9))

	mean = array.mean()
	median = array.median()
	mode = array.mode()
	standard_deviation = array.std()

	array.hist()

filename = "mock_student_data.csv"
read_data(filename)

# %%
# %matplotlib inline

# %%
# %run hw1.py
# Out:
# Age            16.996109
# GPA             2.988447
# Days_missed    18.011139
# dtype: float64
# Age            16.996109
# GPA             2.988447
# Days_missed    18.011139
# dtype: float64
# Age            16.996109
# GPA             2.988447
# Days_missed    18.011139
# dtype: float64
# Age            16.996109
# GPA             2.988447
# Days_missed    18.011139
# dtype: float64

# %%
# %load hw1.py
import numpy as np
import pandas as p
import matplotlib as plt


def read_data(filename):
    array = p.read_csv(filename, usecols = range(1, 9))

    mean = array.mean()
    print(mean)
	
    median = array.median()
    print(mean)

    mode = array.mode()
    print(mean)

    standard_deviation = array.std()
    print(mean)

    array.hist()

filename = "mock_student_data.csv"
read_data(filename)

# %%
# %run hw1.py
# Out:
# Mean:
# Age            16.996109
# GPA             2.988447
# Days_missed    18.011139
# dtype: float64
# Median:
# Age            17
# GPA             3
# Days_missed    18
# dtype: float64
# Mode:
#   First_name Last_name  State  Gender  Age  GPA  Days_missed Graduated
# 0        Amy      Ross  Texas  Female   15    2            6       Yes
# 1        NaN       NaN    NaN     NaN  NaN  NaN           14       NaN
# 2        NaN       NaN    NaN     NaN  NaN  NaN           31       NaN
# Standard Deviation
# Age            1.458067
# GPA            0.818249
# Days_missed    9.629371
# dtype: float64

# %%
# %load hw1.py
#import numpy as np
import pandas as p
#import matplotlib as plt


def read_data(filename):
    array = p.read_csv(filename, usecols = range(1, 9))

    mean = array.mean()
    print("Mean:\n{}".format(mean["Age"]))

    median = array.median()
    print("Median:\n{}".format(median))

    mode = array.mode()
    print("Mode:\n{}".format(mode["Days_missed"]))

    standard_deviation = array.std()
    print("Standard Deviation\n{}".format(standard_deviation))

    array.hist()

filename = "mock_student_data.csv"
read_data(filename)
# Out:
# Mean:
# 16.996108949416342
# Median:
# Age            17
# GPA             3
# Days_missed    18
# dtype: float64
# Mode:
# 0     6
# 1    14
# 2    31
# Name: Days_missed, dtype: float64
# Standard Deviation
# Age            1.458067
# GPA            0.818249
# Days_missed    9.629371
# dtype: float64

# %%
# %run hw1.py
# Out:
# Mean:
# Age            16.996109
# GPA             2.988447
# Days_missed    18.011139
# dtype: float64
#
# Median:
# Age            17
# GPA             3
# Days_missed    18
# dtype: float64
#
# Mode:
#   First_name Last_name  State  Gender  Age  GPA  Days_missed Graduated
# 0        Amy      Ross  Texas  Female   15    2            6       Yes
# 1        NaN       NaN    NaN     NaN  NaN  NaN           14       NaN
# 2        NaN       NaN    NaN     NaN  NaN  NaN           31       NaN
#
# Standard Deviation
# Age            1.458067
# GPA            0.818249
# Days_missed    9.629371
# dtype: float64

# %%
# %load hw1.py
#import numpy as np
import pandas as p
#import matplotlib as plt


def read_data(filename):
    array = p.read_csv(filename, usecols = range(1, 9))

    mean = array.mean()
    print("Mean:\n{}\n".format(mean.head()))

    median = array.median()
    print("Median:\n{}\n".format(median))

    mode = array.mode()
    print("Mode:\n{}\n".format(mode.head()))

    standard_deviation = array.std()
    print("Standard Deviation\n{}\n".format(standard_deviation))

    array["First_name"].plot(kind = "bar")

filename = "mock_student_data.csv"
read_data(filename)
# Out:
# Mean:
# Age            16.996109
# GPA             2.988447
# Days_missed    18.011139
# dtype: float64
#
# Median:
# Age            17
# GPA             3
# Days_missed    18
# dtype: float64
#
# Mode:
#   First_name Last_name  State  Gender  Age  GPA  Days_missed Graduated
# 0        Amy      Ross  Texas  Female   15    2            6       Yes
# 1        NaN       NaN    NaN     NaN  NaN  NaN           14       NaN
# 2        NaN       NaN    NaN     NaN  NaN  NaN           31       NaN
#
# Standard Deviation
# Age            1.458067
# GPA            0.818249
# Days_missed    9.629371
# dtype: float64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-7cb3540ec4cc> in <module>()
#      23
#      24 filename = "mock_student_data.csv"
# ---> 25 read_data(filename)
#
# <ipython-input-52-7cb3540ec4cc> in read_data(filename)
# ...

# %%
# %run hw1.py
# Out:
# Mean:
# Age            16.996109
# GPA             2.988447
# Days_missed    18.011139
# dtype: float64
#
# Median:
# Age            17
# GPA             3
# Days_missed    18
# dtype: float64
#
# Mode:
#   First_name Last_name  State  Gender  Age  GPA  Days_missed Graduated
# 0        Amy      Ross  Texas  Female   15    2            6       Yes
# 1        NaN       NaN    NaN     NaN  NaN  NaN           14       NaN
# 2        NaN       NaN    NaN     NaN  NaN  NaN           31       NaN
#
# Standard Deviation
# Age            1.458067
# GPA            0.818249
# Days_missed    9.629371
# dtype: float64

# %%
# %load hw1.py
#import numpy as np
import pandas as p
#import matplotlib as plt


def read_data(filename):
    array = p.read_csv(filename, usecols = range(1, 9))

    mean = array.mean()
    print("Mean:\n{}\n".format(mean))

    median = array.median()
    print("Median:\n{}\n".format(median))

    mode = array.mode()
    print("Mode:\n{}\n".format(mode))

    standard_deviation = array.std()
    print("Standard Deviation\n{}\n".format(standard_deviation))

    array.hist(figsize = (15, 10))

filename = "mock_student_data.csv"
read_data(filename)
# Out:
# Mean:
# Age            16.996109
# GPA             2.988447
# Days_missed    18.011139
# dtype: float64
#
# Median:
# Age            17
# GPA             3
# Days_missed    18
# dtype: float64
#
# Mode:
#   First_name Last_name  State  Gender  Age  GPA  Days_missed Graduated
# 0        Amy      Ross  Texas  Female   15    2            6       Yes
# 1        NaN       NaN    NaN     NaN  NaN  NaN           14       NaN
# 2        NaN       NaN    NaN     NaN  NaN  NaN           31       NaN
#
# Standard Deviation
# Age            1.458067
# GPA            0.818249
# Days_missed    9.629371
# dtype: float64

# %%
# %run hw1.py
# Out:
# Mean:
# Age            16.996109
# GPA             2.988447
# Days_missed    18.011139
# dtype: float64
#
# Median:
# Age            17
# GPA             3
# Days_missed    18
# dtype: float64
#
# Mode:
#   First_name Last_name  State  Gender Age GPA  Days_missed Graduated
# 0        Amy      Ross  Texas  Female  15   2            6       Yes
# 1                                                       14
# 2                                                       31
#
# Standard Deviation
# Age            1.458067
# GPA            0.818249
# Days_missed    9.629371
# dtype: float64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/dmunger/CAPP30254/HW1/hw1.py in <module>()
#      33     filename = "mock_student_data.csv"
#      34     array = read_data(filename)
# ---> 35     get_genders(array)
#
# /home/dmunger/CAPP30254/HW1/hw1.py in get_genders(array)
#      26
# ...

# %%
# %matplotlib inline

# %%
# %load hw1.py
#import numpy as np
import pandas as p
##import matplotlib as plt
##from genderize import Genderize
import requests
import json

def read_data(filename):
    array = p.read_csv(filename, usecols = range(1, 9))

    mean = array.mean()
    print("Mean:\n{}\n".format(mean.to_string()))

    median = array.median()
    print("Median:\n{}\n".format(median))

    mode = array.mode()
    print("Mode:\n{}\n".format(mode.fillna("")))

    standard_deviation = array.std()
    print("Standard Deviation\n{}\n".format(standard_deviation))

    array.hist(figsize = (15, 10))

    return array

def get_genders(array):
    request = requests.get("http://api.genderize.io?&name=" + name)
    gender = json.loads(request.text)["gender"].title()
	

if __name__ == '__main__':
    filename = "mock_student_data.csv"
    array = read_data(filename)
    get_genders(array)
# Out:
# Mean:
# Age            16.996109
# GPA             2.988447
# Days_missed    18.011139
#
# Median:
# Age            17
# GPA             3
# Days_missed    18
# dtype: float64
#
# Mode:
#   First_name Last_name  State  Gender Age GPA  Days_missed Graduated
# 0        Amy      Ross  Texas  Female  15   2            6       Yes
# 1                                                       14
# 2                                                       31
#
# Standard Deviation
# Age            1.458067
# GPA            0.818249
# Days_missed    9.629371
# dtype: float64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c586404cfb68> in <module>()
#      34     filename = "mock_student_data.csv"
#      35     array = read_data(filename)
# ---> 36     get_genders(array)
#
# <ipython-input-7-c586404cfb68> in get_genders(array)
#      27
#      28 def get_genders(array):
# ...

# %%
# %matplotlib inline
# %run hw1.py
# Out:
# Mean:
# Age            16.996109
# GPA             2.988447
# Days_missed    18.011139
#
# Median:
# Age            17
# GPA             3
# Days_missed    18
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/dmunger/CAPP30254/HW1/hw1.py in <module>()
#      32 if __name__ == '__main__':
#      33     filename = "mock_student_data.csv"
# ---> 34     array = read_data(filename)
#      35     get_genders(array)
#
# /home/dmunger/CAPP30254/HW1/hw1.py in read_data(filename)
#      16
#      17     mode = array.mode().to_string()
# ---> 18     print("Mode:\n{}\n".format(mode.fillna("")))
#      19
#      20     standard_deviation = array.std().to_string()
#
# AttributeError: 'str' object has no attribute 'fillna'

# %%
# %matplotlib inline
# %run hw1.py
# Out:
# Mean:
# Age            16.996109
# GPA             2.988447
# Days_missed    18.011139
#
# Median:
# Age            17
# GPA             3
# Days_missed    18
#
# Mode:
#   First_name Last_name  State  Gender Age GPA  Days_missed Graduated
# 0        Amy      Ross  Texas  Female  15   2            6       Yes
# 1                                                       14
# 2                                                       31
#
# Standard Deviation
# Age            1.458067
# GPA            0.818249
# Days_missed    9.629371
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/dmunger/CAPP30254/HW1/hw1.py in <module>()
#      33     filename = "mock_student_data.csv"
#      34     array = read_data(filename)
# ---> 35     get_genders(array)
#
# /home/dmunger/CAPP30254/HW1/hw1.py in get_genders(array)
#      26
#      27 def get_genders(array):
# ...

# %%
# %matplotlib inline
# %run hw1.py
# Out:
# Mean:
# {}
#  + mean
# Median:
# Age            17
# GPA             3
# Days_missed    18
#
# Mode:
#   First_name Last_name  State  Gender Age GPA  Days_missed Graduated
# 0        Amy      Ross  Texas  Female  15   2            6       Yes
# 1                                                       14
# 2                                                       31
#
# Standard Deviation
# Age            1.458067
# GPA            0.818249
# Days_missed    9.629371
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/dmunger/CAPP30254/HW1/hw1.py in <module>()
#      33     filename = "mock_student_data.csv"
#      34     array = read_data(filename)
# ---> 35     get_genders(array)
#
# /home/dmunger/CAPP30254/HW1/hw1.py in get_genders(array)
#      26
#      27 def get_genders(array):
# ---> 28     request = requests.get("http://api.genderize.io?&name=" + name)
# ...

# %%
# %matplotlib inline
# %run hw1.py
# Out:
# Mean:
# {}
# Age            16.996109
# GPA             2.988447
# Days_missed    18.011139
# Median:
# Age            17
# GPA             3
# Days_missed    18
#
# Mode:
#   First_name Last_name  State  Gender Age GPA  Days_missed Graduated
# 0        Amy      Ross  Texas  Female  15   2            6       Yes
# 1                                                       14
# 2                                                       31
#
# Standard Deviation
# Age            1.458067
# GPA            0.818249
# Days_missed    9.629371
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/dmunger/CAPP30254/HW1/hw1.py in <module>()
#      33     filename = "mock_student_data.csv"
#      34     array = read_data(filename)
# ---> 35     get_genders(array)
#
# /home/dmunger/CAPP30254/HW1/hw1.py in get_genders(array)
#      26
#      27 def get_genders(array):
# ...

# %%
# %run hw1.py
# Out:
# Mean:
# Age            16.996109
# GPA             2.988447
# Days_missed    18.011139
#
# Median:
# Age            17
# GPA             3
# Days_missed    18
#
# Mode:
#   First_name Last_name  State  Gender Age GPA  Days_missed Graduated
# 0        Amy      Ross  Texas  Female  15   2            6       Yes
# 1                                                       14
# 2                                                       31
#
# Standard Deviation
# Age            1.458067
# GPA            0.818249
# Days_missed    9.629371

# %%
# %load hw1.py
#import numpy as np
import pandas as p
##import matplotlib as plt
##from genderize import Genderize
import requests
import json

def read_data(filename):
    array = p.read_csv(filename, usecols = range(1, 9))

    mean = array.mean()
    print("Mean:\n{}\n".format(mean.to_string()))

    median = array.median()
    print("Median:\n{}\n".format(median.to_string()))

    mode = array.mode()
    print("Mode:\n{}\n".format(mode.fillna("").to_string()))

    standard_deviation = array.std()
    print("Standard Deviation\n{}\n".format(standard_deviation.to_string()))

    array.hist(figsize = (15, 10))

    return array

def get_genders(array):
    request = requests.get("http://api.genderize.io?&name=" + name)
    gender = json.loads(request.text)["gender"].title()


if __name__ == '__main__':
    filename = "mock_student_data.csv"
    array = read_data(filename)
    #get_genders(array)
# Out:
# Mean:
# Age            16.996109
# GPA             2.988447
# Days_missed    18.011139
#
# Median:
# Age            17
# GPA             3
# Days_missed    18
#
# Mode:
#   First_name Last_name  State  Gender Age GPA  Days_missed Graduated
# 0        Amy      Ross  Texas  Female  15   2            6       Yes
# 1                                                       14
# 2                                                       31
#
# Standard Deviation
# Age            1.458067
# GPA            0.818249
# Days_missed    9.629371
