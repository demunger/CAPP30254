# %%
# %matplotlib inline

# %%
# %run hw1.py
# Out:
# Mean:
# Age            16.996109
# GPA             2.988447
# Days_missed    18.011139
#
# Median:
# Age            17
# GPA             3
# Days_missed    18
#
# Mode:
#   First_name Last_name  State  Gender Age GPA  Days_missed Graduated
# 0        Amy      Ross  Texas  Female  15   2            6       Yes
# 1                                                       14
# 2                                                       31
#
# Standard Deviation
# Age            1.458067
# GPA            0.818249
# Days_missed    9.629371
#
# Missing Values
# First_name       0
# Last_name        0
# State          116
# Gender         226
# Age            229
# GPA            221
# Days_missed    192
# Graduated        0

# %%
student_array = read_data("mock_student_data.csv")

# %%
summarize_data(student_array)
# Out:
# Mean:
# Age            16.996109
# GPA             2.988447
# Days_missed    18.011139
#
# Median:
# Age            17
# GPA             3
# Days_missed    18
#
# Mode:
#   First_name Last_name  State  Gender Age GPA  Days_missed Graduated
# 0        Amy      Ross  Texas  Female  15   2            6       Yes
# 1                                                       14
# 2                                                       31
#
# Standard Deviation
# Age            1.458067
# GPA            0.818249
# Days_missed    9.629371
#
# Missing Values
# First_name       0
# Last_name        0
# State          116
# Gender         226
# Age            229
# GPA            221
# Days_missed    192
# Graduated        0

# %%
student_array.mean()
# Out:
# Age            16.996109
# GPA             2.988447
# Days_missed    18.011139
# dtype: float64

# %%
temp = student_array.mean()

# %%
temp
# Out:
# Age            16.996109
# GPA             2.988447
# Days_missed    18.011139
# dtype: float64

# %%
print(temp)
# Out:
# Age            16.996109
# GPA             2.988447
# Days_missed    18.011139
# dtype: float64

# %%
graph_data(student_array)

# %%
mean = student_array.mean()

# %%
type(mean)
# Out:
# pandas.core.series.Series

# %%
# %run hw1.py
# Out:
# Mean:
# Age           17.0
# GPA            3.0
# Days_missed   18.0
#
# Median:
# Age            17
# GPA             3
# Days_missed    18
#
# Mode:
# Standard Deviation:
# Age           1.46
# GPA           0.82
# Days_missed   9.63
#
# Missing Values:
# First_name       0
# Last_name        0
# State          116
# Gender         226
# Age            229
# GPA            221
# Days_missed    192
# Graduated        0

# %%
mode = array.mode()

# %%
mode
# Out:
#   First_name Last_name  State  Gender  Age  GPA  Days_missed Graduated
# 0        Amy      Ross  Texas  Female   15    2            6       Yes
# 1        NaN       NaN    NaN     NaN  NaN  NaN           14       NaN
# 2        NaN       NaN    NaN     NaN  NaN  NaN           31       NaN

# %%
type(mode)
# Out:
# pandas.core.frame.DataFrame

# %%
mean = array.mean()

# %%
type(mean)
# Out:
# pandas.core.series.Series

# %%
std_deviation = array.std()
type(std_deviation)
# Out:
# pandas.core.series.Series

# %%
# %run hw1.py
# Out:
# Mean:
# Age           17.0
# GPA            3.0
# Days_missed   18.0
#
# Median:
# Age            17
# GPA             3
# Days_missed    18
#
# Mode:
# First_name Last_name  State  Gender  Age  GPA  Days_missed Graduated
#        Amy      Ross  Texas  Female   15    2            6       Yes
#                                                         14
#                                                         31
#
# Standard Deviation:
# Age           1.46
# GPA           0.82
# Days_missed   9.63
#
# Missing Values:
# First_name       0
# Last_name        0
# State          116
# Gender         226
# Age            229
# GPA            221
# Days_missed    192
# Graduated        0

# %%
mean = array.mean()

# %%
mean
# Out:
# Age            16.996109
# GPA             2.988447
# Days_missed    18.011139
# dtype: float64

# %%
mean["Age"]
# Out:
# 16.996108949416342
