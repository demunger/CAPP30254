# %%
# %matplotlib inline

# %%
# %run hw1.py

# %%
filename = "mock_student_data.csv"
array = read_data(filename)

# %%
sum_array = array.ix[:, 1:]
summarize_data(sum_array)
graph_data(sum_array)
# Out:
# Mean:
# Age           17.0
# GPA            3.0
# Days_missed   18.0
#
# Median:
# Age            17
# GPA             3
# Days_missed    18
#
# Mode:
# First_name Last_name  State  Gender  Age  GPA  Days_missed Graduated
#        Amy      Ross  Texas  Female   15    2            6       Yes
#                                                         14
#                                                         31
#
# Standard Deviation:
# Age           1.46
# GPA           0.82
# Days_missed   9.63
#
# Missing Values:
# First_name       0
# Last_name        0
# State          116
# Gender         226
# Age            229
# GPA            221
# Days_missed    192
# Graduated        0

# %%
array
# Out:
#        ID   First_name   Last_name                 State  Gender  Age  GPA  \
# 0       1        Wayne        Boyd               Florida    Male   19  NaN
# 1       2          Ann    Matthews          Pennsylvania  Female   18    3
# 2       3       George    Matthews                 Texas     NaN   17  NaN
# 3       4        Jerry       Ramos            California    Male   15    2
# 4       5       Andrea     Carroll        North Carolina  Female  NaN    2
# 5       6        Annie      Fisher              Virginia  Female   19  NaN
# 6       7    Stephanie      Barnes              Oklahoma  Female  NaN    3
# 7       8        Janet     Jenkins             Louisiana  Female   15    4
# 8       9        Betty      Miller                   NaN     NaN   17    3
# 9      10        Henry       Woods              Colorado    Male   19    4
# 10     11    Stephanie      Harris                   NaN  Female  NaN  NaN
# ...

# %%
mean_yes = array.ix[array["Graduated"] == "Yes"].mean().round(1)
mean_no = array.ix[array["Graduated"] == "No"].mean().round(1)
    
array_yes = array.loc[array["Graduated"] == "Yes"].fillna({"Age": mean_yes["Age"],
                          "GPA": mean_yes["GPA"],
                          "Days_missed": mean_yes["Days_missed"]})

array_no = array.loc[array["Graduated"] == "No"].fillna({"Age": mean_no["Age"],
                          "GPA": mean_no["GPA"],
                          "Days_missed": mean_no["Days_missed"]})

# %%
array_no
# Out:
#        ID   First_name   Last_name                 State  Gender   Age  GPA  \
# 3       4        Jerry       Ramos            California    Male  15.0    2
# 4       5       Andrea     Carroll        North Carolina  Female  17.1    2
# 6       7    Stephanie      Barnes              Oklahoma  Female  17.1    3
# 8       9        Betty      Miller                   NaN     NaN  17.0    3
# 11     12       Samuel      George               Georgia    Male  15.0    3
# 13     14     Nicholas        Rice               Florida    Male  17.1    2
# 14     15   Jacqueline     Wallace              New York  Female  17.1    2
# 15     16      Phyllis      Burton                 Texas  Female  16.0    3
# 17     18        Karen        Bell           Mississippi  Female  17.0    3
# 22     23         Lori       Lopez                   NaN  Female  19.0    3
# 23     24         Ryan      Porter              New York    Male  15.0    2
# ...

# %%
array_B = array_yes.merge(array_no, how = "outer").sort_index(by = "ID")

# %%
array_B
# Out:
#        ID   First_name   Last_name                 State  Gender   Age  GPA  \
# 0       1        Wayne        Boyd               Florida    Male  19.0  3.5
# 1       2          Ann    Matthews          Pennsylvania  Female  18.0  3.0
# 2       3       George    Matthews                 Texas     NaN  17.0  3.5
# 593     4        Jerry       Ramos            California    Male  15.0  2.0
# 594     5       Andrea     Carroll        North Carolina  Female  17.1  2.0
# 3       6        Annie      Fisher              Virginia  Female  19.0  3.5
# 595     7    Stephanie      Barnes              Oklahoma  Female  17.1  3.0
# 4       8        Janet     Jenkins             Louisiana  Female  15.0  4.0
# 596     9        Betty      Miller                   NaN     NaN  17.0  3.0
# 5      10        Henry       Woods              Colorado    Male  19.0  4.0
# 6      11    Stephanie      Harris                   NaN  Female  17.0  3.5
# ...

# %%
fill_values_A(array)

# %%
fill_values_B(array)

# %%
type(array.loc[0][0])
# Out:
# numpy.int64

# %%
type(array_B.loc[0][0])
# Out:
# numpy.int64

# %%
    mean_yes = array.ix[array["Graduated"] == "Yes"].mean().round(1)
    mean_no = array.ix[array["Graduated"] == "No"].mean().round(1)
    array_yes = fill_empty_values(array.loc[array["Graduated"] == "Yes"], mean_yes)
    array_no = fill_empty_values(array.loc[array["Graduated"] == "No"], mean_no)

# %%
array_B = p.concat([array_yes, array_no]).sort_index(by = "ID")

# %%
array_B
# Out:
#        ID   First_name   Last_name                 State  Gender   Age  GPA  \
# 0       1        Wayne        Boyd               Florida    Male  19.0  3.5
# 1       2          Ann    Matthews          Pennsylvania  Female  18.0  3.0
# 2       3       George    Matthews                 Texas     NaN  17.0  3.5
# 3       4        Jerry       Ramos            California    Male  15.0  2.0
# 4       5       Andrea     Carroll        North Carolina  Female  17.1  2.0
# 5       6        Annie      Fisher              Virginia  Female  19.0  3.5
# 6       7    Stephanie      Barnes              Oklahoma  Female  17.1  3.0
# 7       8        Janet     Jenkins             Louisiana  Female  15.0  4.0
# 8       9        Betty      Miller                   NaN     NaN  17.0  3.0
# 9      10        Henry       Woods              Colorado    Male  19.0  4.0
# 10     11    Stephanie      Harris                   NaN  Female  17.0  3.5
# ...

# %%
array
# Out:
#        ID   First_name   Last_name                 State  Gender  Age  GPA  \
# 0       1        Wayne        Boyd               Florida    Male   19  NaN
# 1       2          Ann    Matthews          Pennsylvania  Female   18    3
# 2       3       George    Matthews                 Texas     NaN   17  NaN
# 3       4        Jerry       Ramos            California    Male   15    2
# 4       5       Andrea     Carroll        North Carolina  Female  NaN    2
# 5       6        Annie      Fisher              Virginia  Female   19  NaN
# 6       7    Stephanie      Barnes              Oklahoma  Female  NaN    3
# 7       8        Janet     Jenkins             Louisiana  Female   15    4
# 8       9        Betty      Miller                   NaN     NaN   17    3
# 9      10        Henry       Woods              Colorado    Male   19    4
# 10     11    Stephanie      Harris                   NaN  Female  NaN  NaN
# ...

# %%
    graduated = array.ix[array["Graduated"] == "Yes"]
    non_graduated = array.ix[array["Graduated"] == "No"]

    mean_grad = graduated.mean().round(1)
    mean_non_grad = non_graduated.mean().round(1)

    array_B = p.concat([fill_values(graduated, mean_grad), fill_values(non_graduated, mean_non_grad)]).sort_index(by = "ID")

# %%
array_B
# Out:
#        ID   First_name   Last_name                 State  Gender   Age  GPA  \
# 0       1        Wayne        Boyd               Florida    Male  19.0  3.5
# 1       2          Ann    Matthews          Pennsylvania  Female  18.0  3.0
# 2       3       George    Matthews                 Texas     NaN  17.0  3.5
# 3       4        Jerry       Ramos            California    Male  15.0  2.0
# 4       5       Andrea     Carroll        North Carolina  Female  17.1  2.0
# 5       6        Annie      Fisher              Virginia  Female  19.0  3.5
# 6       7    Stephanie      Barnes              Oklahoma  Female  17.1  3.0
# 7       8        Janet     Jenkins             Louisiana  Female  15.0  4.0
# 8       9        Betty      Miller                   NaN     NaN  17.0  3.0
# 9      10        Henry       Woods              Colorado    Male  19.0  4.0
# 10     11    Stephanie      Harris                   NaN  Female  17.0  3.5
# ...
